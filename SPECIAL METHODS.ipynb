# %% [markdown]
# SPECIAL METHODS (MAGIC/DUNDER) IN OOP EL 162/234 Object Oriented Programming
# By; Kimberly Botchwey

# %% [markdown]
# 1. Constructors in Python (init())
# Definition
# The __init__() method is a special method (constructor) that is automatically called whenever an object is created from a class.
#
# It is mainly used to initialize the attributes of an object, ensuring that every object starts with the required values.

# %%
# Example 1

class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Ama", 19)

print(s1.name)
print(s1.age)

# Example 2

class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def describe(self):
        print(f"{self.title} by {self.author}")

b1 = Book("OOP", "Dr. Cobbinah")
b1.describe()
# Out:
# Ama
# 19
# OOP by Dr. Cobbinah

# %% [markdown]
# 2. String Representation (str())
# Definition
# The __str__() method provides a human-readable representation of an object.
#
# Whenever the print() function is used on an object, Python automatically calls the __str__() method.
#
# Without this method, Python displays the object's memory location, which is not user-friendly.

# %%
class Student:

    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"Student: {self.name}"

s = Student("Ama")

print(s)
# Out:
# Student: Ama

# %% [markdown]
# 3. Formal Representation (repr())
# Definition
# The __repr__() method provides an official or developer-oriented representation of an object.
#
# It is mainly used for debugging and logging.
#
# If the __str__() method is not defined, Python automatically uses the __repr__() method.

# %%
# Example

class Student:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f"Student('{self.name}')"

s = Student("Ama")

print(repr(s))
# Out:
# Student('Alan')

# %% [markdown]
# 4. Length Method (len())
# Definition
#
# The len() special method allows a custom object to define its own length. It enables Python's built-in len() function to work with user-defined classes.

# %%
# Example

class Playlist:
    def __init__(self, songs):
        self.songs = songs

    def __len__(self):
        return len(self.songs)

p = Playlist(["Song1", "Song2", "Song3"])

print(len(p))

# %% [markdown]
# 5. Equality Comparison (eq())
# Definition
#
# The eq() method defines how two objects should be compared for equality. Instead of comparing memory addresses, it compares the contents of the objects.

# %%
# Example

class Student:
    def __init__(self, student_id):
        self.student_id = student_id

    def __eq__(self, other):
        return self.student_id == other.student_id

s1 = Student(101)
s2 = Student(101)

print(s1 == s2)

# %% [markdown]
# 6. Addition (add())
# Definition
#
# The add() method overloads the addition (+) operator for custom objects. It allows objects to be added together in a meaningful way.

# %%
# Example

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(
            self.x + other.x,
            self.y + other.y
        )

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(1, 3)
v2 = Vector(2, 5)

print(v1 + v2)
# Out:
# (3, 8)

# %% [markdown]
# 7. Subtraction (sub())
# Definition
#
# The sub() method overloads the subtraction (-) operator for objects. It defines how subtraction should behave between two custom objects.

# %%
# Example

class Vector:
    def __init__(self, x):
        self.x = x

    def __sub__(self, other):
        return Vector(self.x - other.x)

    def __str__(self):
        return str(self.x)

v1 = Vector(10)
v2 = Vector(3)

print(v1 - v2)

# %% [markdown]
# 8. Multiplication (mul())
# Definition
#
# The mul() method defines how the multiplication (*) operator works with custom objects. It makes user-defined classes behave like built-in numeric types.

# %%
# Example

class Number:
    def __init__(self, value):
        self.value = value

    def __mul__(self, other):
        return Number(self.value * other.value)

    def __str__(self):
        return str(self.value)

n1 = Number(5)
n2 = Number(4)

print(n1 * n2)

# %% [markdown]
# 9. Item Access (getitem())
# Definition
#
# The getitem() method allows objects to support indexing like lists and tuples. It is called whenever an object is accessed using square brackets.

# %%
# Example

class Grades:
    def __init__(self):
        self.data = [85, 90, 78]

    def __getitem__(self, index):
        return self.data[index]

g = Grades()

print(g[0])
print(g[1])
# Out:
# 85
# 90

# %% [markdown]
# 10. Item Assignment (setitem())
# Definition
#
# The setitem() method allows values inside an object to be modified using indexing. It behaves similarly to assigning values in a list or dictionary

# %%
# Example

class Grades:
    def __init__(self):
        self.data = [85, 90, 78]

    def __setitem__(self, index, value):
        self.data[index] = value

g = Grades()

g[1] = 100

print(g.data)

# %% [markdown]
# 11. Membership Testing (contains())
# Definition
#
# The contains() method defines how the in operator behaves for custom objects. It checks whether a particular item exists in the object.

# %%
# Example

class Course:
    def __init__(self):
        self.students = ["Ella", "Sandra", "Joe"]

    def __contains__(self, student):
        return student in self.students

c = Course()

print("Joe" in c)
print("Gifty" in c)

# %% [markdown]
# 12. Callable Objects (call())
# Definition
#
# The call() method allows an object to behave like a function. Once implemented, the object can be called using parentheses.

# %%
# Example

class Multiplier:
    def __init__(self, factor):
        self.factor = factor

    def __call__(self, number):
        return number * self.factor

double = Multiplier(2)

print(double(10))

# %% [markdown]
# 13. Iteration Support (iter() and next())
# Definition
#
# The iter() and next() methods implement Python's iterator protocol. They allow objects to be used in for loops and other iteration operations.

# %%
# Example

class Counter:
    def __init__(self, limit):
        self.limit = limit
        self.current = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current > self.limit:
            raise StopIteration

        value = self.current
        self.current += 1
        return value

for num in Counter(5):
    print(num)

# %% [markdown]
# 14. Boolean Evaluation (bool())
# Definition
#
# The bool() method determines whether an object is considered True or False. It is automatically used in Boolean expressions and conditional statements.

# %%
# Example

class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def __bool__(self):
        return self.balance > 0

account = BankAccount(500)

if account:
    print("Account is active")

# %% [markdown]
# 15. Destructor (del())
# Definition
#
# The del() method is called when an object is about to be destroyed. It is mainly used for resource cleanup, although modern Python often prefers context managers.

# %%
# Example

class Resource:
    def __init__(self):
        print("Resource allocated")

    def __del__(self):
        print("Resource released")

r = Resource()
# Out:
# Resource allocated

# %% [markdown]
# Special Methods in Summary
# Special Method	Purpose
# __init__()	Initialize object
# __str__()	User-friendly string representation
# __repr__()	Developer/debug representation
# __len__()	Define object length
# __eq__()	Equality comparison
# __lt__(), __gt__(), etc.	Relational comparisons
# __add__(), __sub__(), __mul__()	Operator overloading
# __getitem__()	Index access
# __setitem__()	Index assignment
# __contains__()	Membership testing
# __iter__()	Create iterator
# __next__()	Return next item
# __call__()	Make object callable
# __bool__()	Truth-value testing
# __del__()	Destructor
